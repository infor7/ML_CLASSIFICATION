# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.datasets import load_iris


arr1 = np.random.normal(1, 1, 80)
arr2 = np.random.normal(1,1, (80,100))
ind = arr2.argsort()
arr2[ind[::-1]]
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-55-68305fef0d2e> in <module>
#       7 arr2 = np.random.normal(1,1, (80,100))
#       8 ind = arr2.argsort()
# ----> 9 arr2[ind[::-1]]
#
# IndexError: index 81 is out of bounds for axis 0 with size 80

# %%
iris_dataset = load_iris()
data = iris_dataset.data
target = iris_dataset.target

uniqueValues, occurCount = np.unique(target, return_counts=True)
uniqueValues
occurCount.sum()
# Out:
# 150

# %%
import numpy as np
arr1 = np.random.normal(1, 1, 80)
arr2 = np.random.normal(1,1, (80,100))
arr1inds = arr1.argsort()
sorted_arr1 = arr1[arr1inds[::-1]]
sorted_arr2 = arr2[arr1inds[::-1]]
print(sorted_arr1)
print(sorted_arr2)
data
# Out:
# [ 3.82464948  3.44289786  2.97902729  2.97439201  2.45133384  2.36661195
#   2.36501825  2.35840904  2.28986691  2.24985178  2.17073013  2.12720797
#   2.05888242  1.99145891  1.9313987   1.92834698  1.91646581  1.85502132
#   1.78970337  1.70223712  1.54136071  1.47828073  1.42090861  1.3938949
#   1.28599683  1.25076053  1.19877953  1.16957987  1.11688967  1.10513357
#   1.0906256   1.07117096  1.01891459  1.00205882  0.97426518  0.95926421
#   0.95603966  0.91537516  0.90050296  0.88690406  0.88455822  0.88412182
#   0.84871181  0.84357368  0.82841375  0.79239777  0.7576301   0.74982363
#   0.73869377  0.72312253  0.66788857  0.66321895  0.57799832  0.53020035
#   0.52064292  0.49528509  0.42127232  0.40546587  0.34893704  0.34887312
#   0.31597936  0.28342357  0.27872631  0.22004398  0.19092112  0.18564774
#   0.18483423  0.14740832  0.0917789   0.04762056  0.0427127   0.01496913
#  -0.0056215  -0.07637486 -0.09113161 -0.10822346 -0.18530695 -0.64815125
#  -0.68137398 -0.92338648]
# [[ 3.67008342  3.13805671  1.16516897 ...  2.41135901  1.02965237
#    1.13887432]
#  [ 2.96225002 -1.08783871  2.36228892 ...  2.86861202  1.6659563
#    1.08114284]
#  [ 1.01910696  0.47509321  2.43183754 ... -0.02922406  1.05689345
#    3.37316191]
#  ...
#  [ 0.04125968  1.51749307  0.15507106 ...  1.99069492 -0.01408517
#    2.18170917]
#  [ 1.24512534  1.11766624  1.44997946 ...  3.59278859  1.31401736
#    0.76704068]
#  [ 0.19249903  0.10974118  0.58441113 ...  1.54565976  0.2873394
#    1.21686615]]
# array([[5.1, 3.5, 1.4, 0.2],
#        [4.9, 3. , 1.4, 0.2],
#        [4.7, 3.2, 1.3, 0.2],
#        [4.6, 3.1, 1.5, 0.2],
#        [5. , 3.6, 1.4, 0.2],
#        [5.4, 3.9, 1.7, 0.4],
#        [4.6, 3.4, 1.4, 0.3],
#        [5. , 3.4, 1.5, 0.2],
#        [4.4, 2.9, 1.4, 0.2],
#        [4.9, 3.1, 1.5, 0.1],
#        [5.4, 3.7, 1.5, 0.2],
#        [4.8, 3.4, 1.6, 0.2],
#        [4.8, 3. , 1.4, 0.1],
#        [4.3, 3. , 1.1, 0.1],
#        [5.8, 4. , 1.2, 0.2],
#        [5.7, 4.4, 1.5, 0.4],
#        [5.4, 3.9, 1.3, 0.4],
#        [5.1, 3.5, 1.4, 0.3],
#        [5.7, 3.8, 1.7, 0.3],
#        [5.1, 3.8, 1.5, 0.3],
#        [5.4, 3.4, 1.7, 0.2],
#        [5.1, 3.7, 1.5, 0.4],
#        [4.6, 3.6, 1. , 0.2],
#        [5.1, 3.3, 1.7, 0.5],
#        [4.8, 3.4, 1.9, 0.2],
#        [5. , 3. , 1.6, 0.2],
#        [5. , 3.4, 1.6, 0.4],
#        [5.2, 3.5, 1.5, 0.2],
#        [5.2, 3.4, 1.4, 0.2],
#        [4.7, 3.2, 1.6, 0.2],
#        [4.8, 3.1, 1.6, 0.2],
#        [5.4, 3.4, 1.5, 0.4],
#        [5.2, 4.1, 1.5, 0.1],
#        [5.5, 4.2, 1.4, 0.2],
#        [4.9, 3.1, 1.5, 0.2],
#        [5. , 3.2, 1.2, 0.2],
#        [5.5, 3.5, 1.3, 0.2],
#        [4.9, 3.6, 1.4, 0.1],
#        [4.4, 3. , 1.3, 0.2],
#        [5.1, 3.4, 1.5, 0.2],
#        [5. , 3.5, 1.3, 0.3],
#        [4.5, 2.3, 1.3, 0.3],
#        [4.4, 3.2, 1.3, 0.2],
#        [5. , 3.5, 1.6, 0.6],
#        [5.1, 3.8, 1.9, 0.4],
#        [4.8, 3. , 1.4, 0.3],
#        [5.1, 3.8, 1.6, 0.2],
#        [4.6, 3.2, 1.4, 0.2],
#        [5.3, 3.7, 1.5, 0.2],
#        [5. , 3.3, 1.4, 0.2],
#        [7. , 3.2, 4.7, 1.4],
#        [6.4, 3.2, 4.5, 1.5],
#        [6.9, 3.1, 4.9, 1.5],
#        [5.5, 2.3, 4. , 1.3],
#        [6.5, 2.8, 4.6, 1.5],
#        [5.7, 2.8, 4.5, 1.3],
#        [6.3, 3.3, 4.7, 1.6],
#        [4.9, 2.4, 3.3, 1. ],
#        [6.6, 2.9, 4.6, 1.3],
#        [5.2, 2.7, 3.9, 1.4],
#        [5. , 2. , 3.5, 1. ],
#        [5.9, 3. , 4.2, 1.5],
#        [6. , 2.2, 4. , 1. ],
#        [6.1, 2.9, 4.7, 1.4],
#        [5.6, 2.9, 3.6, 1.3],
#        [6.7, 3.1, 4.4, 1.4],
#        [5.6, 3. , 4.5, 1.5],
#        [5.8, 2.7, 4.1, 1. ],
#        [6.2, 2.2, 4.5, 1.5],
#        [5.6, 2.5, 3.9, 1.1],
#        [5.9, 3.2, 4.8, 1.8],
#        [6.1, 2.8, 4. , 1.3],
#        [6.3, 2.5, 4.9, 1.5],
#        [6.1, 2.8, 4.7, 1.2],
#        [6.4, 2.9, 4.3, 1.3],
#        [6.6, 3. , 4.4, 1.4],
#        [6.8, 2.8, 4.8, 1.4],
#        [6.7, 3. , 5. , 1.7],
#        [6. , 2.9, 4.5, 1.5],
#        [5.7, 2.6, 3.5, 1. ],
#        [5.5, 2.4, 3.8, 1.1],
#        [5.5, 2.4, 3.7, 1. ],
#        [5.8, 2.7, 3.9, 1.2],
#        [6. , 2.7, 5.1, 1.6],
#        [5.4, 3. , 4.5, 1.5],
#        [6. , 3.4, 4.5, 1.6],
#        [6.7, 3.1, 4.7, 1.5],
#        [6.3, 2.3, 4.4, 1.3],
#        [5.6, 3. , 4.1, 1.3],
#        [5.5, 2.5, 4. , 1.3],
#        [5.5, 2.6, 4.4, 1.2],
#        [6.1, 3. , 4.6, 1.4],
#        [5.8, 2.6, 4. , 1.2],
#        [5. , 2.3, 3.3, 1. ],
#        [5.6, 2.7, 4.2, 1.3],
#        [5.7, 3. , 4.2, 1.2],
#        [5.7, 2.9, 4.2, 1.3],
#        [6.2, 2.9, 4.3, 1.3],
#        [5.1, 2.5, 3. , 1.1],
#        [5.7, 2.8, 4.1, 1.3],
#        [6.3, 3.3, 6. , 2.5],
#        [5.8, 2.7, 5.1, 1.9],
#        [7.1, 3. , 5.9, 2.1],
#        [6.3, 2.9, 5.6, 1.8],
#        [6.5, 3. , 5.8, 2.2],
#        [7.6, 3. , 6.6, 2.1],
#        [4.9, 2.5, 4.5, 1.7],
#        [7.3, 2.9, 6.3, 1.8],
#        [6.7, 2.5, 5.8, 1.8],
#        [7.2, 3.6, 6.1, 2.5],
#        [6.5, 3.2, 5.1, 2. ],
#        [6.4, 2.7, 5.3, 1.9],
#        [6.8, 3. , 5.5, 2.1],
#        [5.7, 2.5, 5. , 2. ],
#        [5.8, 2.8, 5.1, 2.4],
#        [6.4, 3.2, 5.3, 2.3],
#        [6.5, 3. , 5.5, 1.8],
#        [7.7, 3.8, 6.7, 2.2],
#        [7.7, 2.6, 6.9, 2.3],
#        [6. , 2.2, 5. , 1.5],
#        [6.9, 3.2, 5.7, 2.3],
#        [5.6, 2.8, 4.9, 2. ],
#        [7.7, 2.8, 6.7, 2. ],
#        [6.3, 2.7, 4.9, 1.8],
#        [6.7, 3.3, 5.7, 2.1],
#        [7.2, 3.2, 6. , 1.8],
#        [6.2, 2.8, 4.8, 1.8],
#        [6.1, 3. , 4.9, 1.8],
#        [6.4, 2.8, 5.6, 2.1],
#        [7.2, 3. , 5.8, 1.6],
#        [7.4, 2.8, 6.1, 1.9],
#        [7.9, 3.8, 6.4, 2. ],
#        [6.4, 2.8, 5.6, 2.2],
#        [6.3, 2.8, 5.1, 1.5],
#        [6.1, 2.6, 5.6, 1.4],
#        [7.7, 3. , 6.1, 2.3],
#        [6.3, 3.4, 5.6, 2.4],
#        [6.4, 3.1, 5.5, 1.8],
#        [6. , 3. , 4.8, 1.8],
#        [6.9, 3.1, 5.4, 2.1],
#        [6.7, 3.1, 5.6, 2.4],
#        [6.9, 3.1, 5.1, 2.3],
#        [5.8, 2.7, 5.1, 1.9],
#        [6.8, 3.2, 5.9, 2.3],
#        [6.7, 3.3, 5.7, 2.5],
#        [6.7, 3. , 5.2, 2.3],
#        [6.3, 2.5, 5. , 1.9],
#        [6.5, 3. , 5.2, 2. ],
#        [6.2, 3.4, 5.4, 2.3],
#        [5.9, 3. , 5.1, 1.8]])

# %%
test = np.c_[target, data[:,0]]
test[test[:,1].argsort()]
# Out:
# array([[0. , 4.3],
#        [0. , 4.4],
#        [0. , 4.4],
#        [0. , 4.4],
#        [0. , 4.5],
#        [0. , 4.6],
#        [0. , 4.6],
#        [0. , 4.6],
#        [0. , 4.6],
#        [0. , 4.7],
#        [0. , 4.7],
#        [0. , 4.8],
#        [0. , 4.8],
#        [0. , 4.8],
#        [0. , 4.8],
#        [0. , 4.8],
#        [1. , 4.9],
#        [2. , 4.9],
#        [0. , 4.9],
#        [0. , 4.9],
#        [0. , 4.9],
#        [0. , 4.9],
#        [0. , 5. ],
#        [0. , 5. ],
#        [0. , 5. ],
#        [0. , 5. ],
#        [0. , 5. ],
#        [1. , 5. ],
#        [0. , 5. ],
#        [1. , 5. ],
#        [0. , 5. ],
#        [0. , 5. ],
#        [0. , 5.1],
#        [0. , 5.1],
#        [1. , 5.1],
#        [0. , 5.1],
#        [0. , 5.1],
#        [0. , 5.1],
#        [0. , 5.1],
#        [0. , 5.1],
#        [0. , 5.1],
#        [0. , 5.2],
#        [0. , 5.2],
#        [0. , 5.2],
#        [1. , 5.2],
#        [0. , 5.3],
#        [1. , 5.4],
#        [0. , 5.4],
#        [0. , 5.4],
#        [0. , 5.4],
#        [0. , 5.4],
#        [0. , 5.4],
#        [0. , 5.5],
#        [1. , 5.5],
#        [0. , 5.5],
#        [1. , 5.5],
#        [1. , 5.5],
#        [1. , 5.5],
#        [1. , 5.5],
#        [1. , 5.6],
#        [2. , 5.6],
#        [1. , 5.6],
#        [1. , 5.6],
#        [1. , 5.6],
#        [1. , 5.6],
#        [1. , 5.7],
#        [1. , 5.7],
#        [1. , 5.7],
#        [0. , 5.7],
#        [1. , 5.7],
#        [2. , 5.7],
#        [0. , 5.7],
#        [1. , 5.7],
#        [1. , 5.8],
#        [0. , 5.8],
#        [1. , 5.8],
#        [2. , 5.8],
#        [2. , 5.8],
#        [1. , 5.8],
#        [2. , 5.8],
#        [2. , 5.9],
#        [1. , 5.9],
#        [1. , 5.9],
#        [1. , 6. ],
#        [1. , 6. ],
#        [2. , 6. ],
#        [1. , 6. ],
#        [1. , 6. ],
#        [2. , 6. ],
#        [2. , 6.1],
#        [2. , 6.1],
#        [1. , 6.1],
#        [1. , 6.1],
#        [1. , 6.1],
#        [1. , 6.1],
#        [1. , 6.2],
#        [1. , 6.2],
#        [2. , 6.2],
#        [2. , 6.2],
#        [1. , 6.3],
#        [2. , 6.3],
#        [2. , 6.3],
#        [1. , 6.3],
#        [2. , 6.3],
#        [2. , 6.3],
#        [1. , 6.3],
#        [2. , 6.3],
#        [2. , 6.3],
#        [2. , 6.4],
#        [2. , 6.4],
#        [2. , 6.4],
#        [1. , 6.4],
#        [2. , 6.4],
#        [1. , 6.4],
#        [2. , 6.4],
#        [2. , 6.5],
#        [2. , 6.5],
#        [2. , 6.5],
#        [1. , 6.5],
#        [2. , 6.5],
#        [1. , 6.6],
#        [1. , 6.6],
#        [1. , 6.7],
#        [2. , 6.7],
#        [2. , 6.7],
#        [1. , 6.7],
#        [1. , 6.7],
#        [2. , 6.7],
#        [2. , 6.7],
#        [2. , 6.7],
#        [2. , 6.8],
#        [1. , 6.8],
#        [2. , 6.8],
#        [2. , 6.9],
#        [2. , 6.9],
#        [1. , 6.9],
#        [2. , 6.9],
#        [1. , 7. ],
#        [2. , 7.1],
#        [2. , 7.2],
#        [2. , 7.2],
#        [2. , 7.2],
#        [2. , 7.3],
#        [2. , 7.4],
#        [2. , 7.6],
#        [2. , 7.7],
#        [2. , 7.7],
#        [2. , 7.7],
#        [2. , 7.7],
#        [2. , 7.9]])
